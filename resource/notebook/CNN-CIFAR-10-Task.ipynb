# %% [markdown]
# <img src = "https://i.imgur.com/XoRDxQJ.png" align = "center">

# %% [markdown]
# ###Reference:
#
#
#
# *   https://stackabuse.com/image-recognition-in-python-with-tensorflow-and-keras/

# %%
import numpy
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, BatchNormalization, Activation
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.constraints import maxnorm
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %%
from keras.datasets import cifar10

# %%
# loading in the data

# %%
# normalize the inputs from 0-255 to between 0 and 1 by dividing by 255

# %%
#see the data shape

# %%
# one hot encode outputs

# %%
#build the model

model = Sequential()
# add convolutional layer 2D
# add max pooling layer 2D
# add dropout layer

#add flatten layer
#add dense layer as output
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
#show model summary

# %%
#compile the model using loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy']

# %%
#train the model

# %%
# Model evaluation by showing accuracy
